# %% [markdown]
# ## El comando print
#
# Diferencia entre la salida normal y el comando print

# %%
3+6
print(4)
7
# Out:
# 4
# 7

# %%
print("el valor de la variable es ", 4, " y se concatena con otro texto")
# Out:
# el valor de la variable es  4  y se concatena con otro texto

# %% [markdown]
# Añadir varios elementos al comando

# %%
print(f"el valor de la variable es {4} y se concatena con otro texto")
# Out:
# el valor de la variable es 4 y se concatena con otro texto

# %% [markdown]
# ## El comando Input
# Captura de la entrada de teclado

# %%
nombre  = input("escribe tu nombre")
print(nombre)
# Out:
# Manuel

# %% [markdown]
# Combinando input con print

# %% [markdown]
# ## Operaciones matemáticas con la entrada del input
#
# Sabiendo que una maraton son 42.2km escribiremos un programa que le preguntara al usuario cuantos minutos tardó en realizarla, y con eso calculará el ritmo medio al que corrió.

# %%
DISTANCIAMARATON = 42.2
#TU CÓDIGO AQUÍ

tiempo = float(input("Cuantos minutos tardaste?"))
print(f"tarde {tiempo} minutos, valor medio es {DISTANCIAMARATON / tiempo}")
# Out:
# tarde 19.0 minutos, valor medio es 2.2210526315789476
