# %% [markdown]
# ## Ejercicio
#
# Estamos trabajando con una serie de datos los cuales vienen almacenados en cadenas del tipo:
#
# "'Categoria': 'valor numérico' "
#
# como por ejemplo:

# %%
datoProblema = "Peso : 82.3"

# %% [markdown]
# Crea una función que usando el método find obtenga la posicion del carácter : y en el return devuelva un float con el valor contenido tras dicho carácter

# %%
def EncuentraValor(dato):
  get_dato = dato[dato.find(":") + 1:]
  print(get_dato)
  return float(get_dato)

EncuentraValor(datoProblema)
# Out:
#  82.3
# 82.3

# %% [markdown]
# Si lo has hecho bien la siguiente instrucción no deberia dar errores

# %%
assert EncuentraValor("Peso : 82.3")==82.3,'Ejercicio incompleto'
assert EncuentraValor("Peso : 33")==33,'Estas usando parámetros bien?'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 assert EncuentraValor("Peso : 82.3")==82.3,'Ejercicio incompleto'
#       2 assert EncuentraValor("Peso : 33")==33,'Estas usando parámetros bien?'
#
# AssertionError: Ejercicio incompleto

# %% [markdown]
#   <details>
# <summary>Pincha aqui para ver la solución</summary>
# <pre><code>
# def EncuentraValor(dato):
#     posicion = dato.find(':')
#     valor = dato[posicion+1:]
#     valor = float(valor)
#     return valor
# <code><pre>
# </details>
