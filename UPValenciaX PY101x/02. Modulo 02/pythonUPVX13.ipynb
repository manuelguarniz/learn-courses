# %% [markdown]
# #Operaciones aritméticas

# %%
3+2

# %%
3-2

# %%
3*2

# %%
3/2 #nota en python 2 esto devolvería 1

# %%
3%2
# Out:
# 1

# %%
3**2

# %%
- 3

# %%
+ 3

# %% [markdown]
# # Precedencia

# %%
3*2+1

# %%
3**2+1

# %%
3**(2+1)

# %% [markdown]
# #cuidado!
#
# estas operaciones no modifican el valor de las variables así que si hicieramos esto

# %%
a=3
b=2
a+b
# Out:
# 5

# %% [markdown]
# tenemos un 5 en pantalla que no hemos almacenado en ningún sitio para esto tendremos que asignar el resultado a una variable

# %%
c=a+b

print(f"la variable c es: {c}")
# Out:
# la variable c es: 5

# %% [markdown]
# #Operadores con las cadenas

# %%
"hola " + " mundo"

# %%
"monja" * 5

# %%
"monja" + 5
